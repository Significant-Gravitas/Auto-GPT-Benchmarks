# %%
import json
import os
import glob

# Use glob to get all json files in the directory
json_files = glob.glob('reports/beebot/*.json')

data = []

# Iterate through the list of json files
for file in json_files:
    with open(file, 'r') as f:
        # Load the JSON data from the file
        json_data = json.load(f)
        
        # Append the data to your list
        data.append(json_data)

# %%
import pandas as pd

# Convert the list of dictionaries into a DataFrame
df = pd.json_normalize(data)

# %%
df
# Out:
#               command   completion_time metrics.run_time  \
# 0   agbenchmark start  2023-07-23-08:29   738.31 seconds
# 1   agbenchmark start  2023-07-23-16:22    60.24 seconds
# 2   agbenchmark start  2023-07-23-19:16   529.67 seconds
# 3   agbenchmark start  2023-07-23-19:39   740.02 seconds
# 4   agbenchmark start  2023-07-23-19:44   589.81 seconds
# 5   agbenchmark start  2023-07-23-20:06   708.08 seconds
# 6   agbenchmark start  2023-07-23-21:16    767.4 seconds
# 7   agbenchmark start  2023-07-23-21:07    64.49 seconds
# 8   agbenchmark start  2023-07-23-22:36   585.49 seconds
# 9   agbenchmark start  2023-07-24-08:26   462.32 seconds
# 10  agbenchmark start  2023-07-20-22:49    62.25 seconds
# 11  agbenchmark start  2023-07-25-00:11  1177.98 seconds
# 12  agbenchmark start  2023-07-25-01:06    64.82 seconds
# 13  agbenchmark start  2023-07-25-01:36    60.65 seconds
# 14  agbenchmark start  2023-07-25-03:32  1115.01 seconds
# 15  agbenchmark start  2023-07-25-03:57   1315.6 seconds
# 16  agbenchmark start  2023-07-25-04:23  1445.26 seconds
# 17  agbenchmark start  2023-07-25-04:37  1067.76 seconds
# 18  agbenchmark start  2023-07-25-08:42  1415.61 seconds
# 19  agbenchmark start  2023-07-20-23:18    39.78 seconds
# 20  agbenchmark start  2023-07-20-22:52   514.61 seconds
# 21  agbenchmark start  2023-07-20-23:44    37.62 seconds
# 22  agbenchmark start  2023-07-21-00:31   624.79 seconds
# 23  agbenchmark start  2023-07-21-08:19    66.62 seconds
# 24  agbenchmark start  2023-07-21-18:27   525.53 seconds
# 25  agbenchmark start  2023-07-22-08:17    60.73 seconds
# 26  agbenchmark start  2023-07-22-15:11     61.2 seconds
#
#    metrics.highest_difficulty  \
# 0                 advanced: 5
# 1         No successful tests
# 2                 advanced: 5
# 3                 advanced: 5
# 4                 advanced: 5
# 5                 advanced: 5
# 6                 advanced: 5
# 7         No successful tests
# 8                 advanced: 5
# 9                 advanced: 5
# 10        No successful tests
# 11                advanced: 5
# 12        No successful tests
# 13        No successful tests
# 14                advanced: 5
# 15                advanced: 5
# 16                advanced: 5
# 17                advanced: 5
# 18                advanced: 5
# 19        No successful tests
# 20                advanced: 5
# 21        No successful tests
# 22                advanced: 5
# 23        No successful tests
# 24                advanced: 5
# 25        No successful tests
# 26        No successful tests
#
#                         tests.TestWriteFile.data_path  \
# 0         agbenchmark/challenges/interface/write_file
# 1         agbenchmark/challenges/interface/write_file
# 2         agbenchmark/challenges/interface/write_file
# 3         agbenchmark/challenges/interface/write_file
# 4         agbenchmark/challenges/interface/write_file
# 5         agbenchmark/challenges/interface/write_file
# 6         agbenchmark/challenges/interface/write_file
# 7         agbenchmark/challenges/interface/write_file
# 8         agbenchmark/challenges/interface/write_file
# 9         agbenchmark/challenges/interface/write_file
# 10        agbenchmark/challenges/interface/write_file
# 11  agbenchmark/challenges/interface/write_file/da...
# 12  agbenchmark/challenges/interface/write_file/da...
# 13  agbenchmark/challenges/interface/write_file/da...
# 14  agbenchmark/challenges/interface/write_file/da...
# 15  agbenchmark/challenges/interface/write_file/da...
# 16  agbenchmark/challenges/interface/write_file/da...
# 17  agbenchmark/challenges/interface/write_file/da...
# 18  agbenchmark/challenges/interface/write_file/da...
# 19        agbenchmark/challenges/interface/write_file
# 20        agbenchmark/challenges/interface/write_file
# 21        agbenchmark/challenges/interface/write_file
# 22        agbenchmark/challenges/interface/write_file
# 23        agbenchmark/challenges/interface/write_file
# 24        agbenchmark/challenges/interface/write_file
# 25        agbenchmark/challenges/interface/write_file
# 26        agbenchmark/challenges/interface/write_file
#
#     tests.TestWriteFile.is_regression  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# 5                               False
# 6                               False
# 7                               False
# 8                               False
# 9                               False
# 10                              False
# 11                              False
# 12                              False
# 13                              False
# 14                              False
# 15                              False
# 16                              False
# 17                              False
# 18                              False
# 19                              False
# 20                              False
# 21                              False
# 22                              False
# 23                              False
# 24                              False
# 25                              False
# 26                              False
#
#                            tests.TestWriteFile.task  \
# 0   Print the the capital of America to a .txt file
# 1   Print the the capital of America to a .txt file
# 2   Print the the capital of America to a .txt file
# 3   Print the the capital of America to a .txt file
# 4   Print the the capital of America to a .txt file
# 5   Print the the capital of America to a .txt file
# 6   Print the the capital of America to a .txt file
# 7   Print the the capital of America to a .txt file
# 8   Print the the capital of America to a .txt file
# 9   Print the the capital of America to a .txt file
# 10  Print the the capital of America to a .txt file
# 11  Print the the capital of America to a .txt file
# 12  Print the the capital of America to a .txt file
# 13  Print the the capital of America to a .txt file
# 14  Print the the capital of America to a .txt file
# 15  Print the the capital of America to a .txt file
# 16  Print the the capital of America to a .txt file
# 17  Print the the capital of America to a .txt file
# 18  Print the the capital of America to a .txt file
# 19  Print the the capital of America to a .txt file
# 20  Print the the capital of America to a .txt file
# 21  Print the the capital of America to a .txt file
# 22  Print the the capital of America to a .txt file
# 23  Print the the capital of America to a .txt file
# 24  Print the the capital of America to a .txt file
# 25  Print the the capital of America to a .txt file
# 26  Print the the capital of America to a .txt file
#
#    tests.TestWriteFile.answer tests.TestWriteFile.description  \
# 0                  Washington       Tests the writing to file
# 1                  Washington       Tests the writing to file
# 2                  Washington       Tests the writing to file
# 3                  Washington       Tests the writing to file
# 4                  Washington       Tests the writing to file
# 5                  Washington       Tests the writing to file
# 6                  Washington       Tests the writing to file
# 7                  Washington       Tests the writing to file
# 8                  Washington       Tests the writing to file
# 9                  Washington       Tests the writing to file
# 10                 Washington       Tests the writing to file
# 11                 Washington       Tests the writing to file
# 12                 Washington       Tests the writing to file
# 13                 Washington       Tests the writing to file
# 14                 Washington       Tests the writing to file
# 15                 Washington       Tests the writing to file
# 16                 Washington       Tests the writing to file
# 17                 Washington       Tests the writing to file
# 18                 Washington       Tests the writing to file
# 19                 Washington       Tests the writing to file
# 20                 Washington       Tests the writing to file
# 21                 Washington       Tests the writing to file
# 22                 Washington       Tests the writing to file
# 23                 Washington       Tests the writing to file
# 24                 Washington       Tests the writing to file
# 25                 Washington       Tests the writing to file
# 26                 Washington       Tests the writing to file
#
#    tests.TestWriteFile.metrics.difficulty  ...  \
# 0                               interface  ...
# 1                               interface  ...
# 2                               interface  ...
# 3                               interface  ...
# 4                               interface  ...
# 5                               interface  ...
# 6                               interface  ...
# 7                               interface  ...
# 8                               interface  ...
# 9                               interface  ...
# 10                              interface  ...
# 11                              interface  ...
# 12                              interface  ...
# 13                              interface  ...
# 14                              interface  ...
# 15                              interface  ...
# 16                              interface  ...
# 17                              interface  ...
# 18                              interface  ...
# 19                              interface  ...
# 20                              interface  ...
# 21                              interface  ...
# 22                              interface  ...
# 23                              interface  ...
# 24                              interface  ...
# 25                              interface  ...
# 26                              interface  ...
#
#     tests.TestReturnCode_Tests.reached_cutoff  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                      False
# 15                                      False
# 16                                      False
# 17                                      False
# 18                                       True
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
#
#     tests.TestRememberMultiplePhrasesWithNoise.category  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                           [memory]
# 12                                           [memory]
# 13                                           [memory]
# 14                                           [memory]
# 15                                           [memory]
# 16                                           [memory]
# 17                                           [memory]
# 18                                           [memory]
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#    tests.TestRetrieval3.category  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                   [retrieval]
# 12                   [retrieval]
# 13                   [retrieval]
# 14                   [retrieval]
# 15                   [retrieval]
# 16                   [retrieval]
# 17                   [retrieval]
# 18                   [retrieval]
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
#
#       tests.TestReturnCode_Simple.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  challenges/test_all.py::TestReturnCode_Simple:...
# 13  challenges/test_all.py::TestReturnCode_Simple:...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#               tests.TestAdaptLink.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  challenges/test_all.py::TestAdaptLink::test_me...
# 13  challenges/test_all.py::TestAdaptLink::test_me...
# 14                                     assert 1 in []
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  challenges/test_all.py::TestAdaptLink::test_me...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#        tests.TestReturnCode_Write.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  challenges/test_all.py::TestReturnCode_Write::...
# 13  challenges/test_all.py::TestReturnCode_Write::...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#    tests.TestAdaptSimpleTypoWithGuidance.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  challenges/test_all.py::TestAdaptSimpleTypoWit...
# 13  challenges/test_all.py::TestAdaptSimpleTypoWit...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                  assert 1 in [0.0]
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#    tests.TestFunctionCodeGeneration.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  challenges/test_all.py::TestFunctionCodeGenera...
# 13  challenges/test_all.py::TestFunctionCodeGenera...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#       tests.TestReturnCode_Modify.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  challenges/test_all.py::TestReturnCode_Modify:...
# 13  challenges/test_all.py::TestReturnCode_Modify:...
# 14                                                NaN
# 15                                  assert 1 in [0.0]
# 16                                  assert 1 in [0.0]
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#       tests.TestDebugMultipleTypo.metrics.fail_reason
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  challenges/test_all.py::TestDebugMultipleTypo:...
# 13  challenges/test_all.py::TestDebugMultipleTypo:...
# 14                                  assert 1 in [0.0]
# 15                                  assert 1 in [0.0]
# 16                                  assert 1 in [0.0]
# 17                                                NaN
# 18                                  assert 1 in [0.0]
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
# [27 rows x 385 columns]
