# %%
import json
import os
import glob

# Use glob to get all json files in the directory
json_files = glob.glob('reports/mini-agi/*.json')

data = []

# Iterate through the list of json files
for file in json_files:
    with open(file, 'r') as f:
        # Load the JSON data from the file
        json_data = json.load(f)
        
        # Append the data to your list
        data.append(json_data)

# %%
import pandas as pd

# Convert the list of dictionaries into a DataFrame
df = pd.json_normalize(data)

# %%
df
# Out:
#                                               command   completion_time  \
# 0              agbenchmark start --test TestWriteFile  2023-07-17-13:34
# 1   agbenchmark start --test TestRememberMultipleW...  2023-07-17-21:24
# 2   agbenchmark start --test TestRememberMultipleW...  2023-07-17-21:19
# 3   agbenchmark start --test TestRememberMultipleP...  2023-07-17-21:28
# 4   agbenchmark start --test TestRememberMultipleP...  2023-07-17-21:32
# ..                                                ...               ...
# 58                                  agbenchmark start  2023-07-25-01:44
# 59                                  agbenchmark start  2023-07-25-03:21
# 60                                  agbenchmark start  2023-07-25-03:44
# 61                                  agbenchmark start  2023-07-25-04:08
# 62                                  agbenchmark start  2023-07-25-08:28
#
#    metrics.run_time metrics.highest_difficulty  \
# 0     23.83 seconds               interface: 1
# 1     77.71 seconds            intermediate: 4
# 2      74.3 seconds        No successful tests
# 3     60.86 seconds        No successful tests
# 4     73.04 seconds        No successful tests
# ..              ...                        ...
# 58   512.66 seconds                advanced: 5
# 59    440.2 seconds                advanced: 5
# 60   597.06 seconds                advanced: 5
# 61   530.55 seconds                advanced: 5
# 62   518.48 seconds                advanced: 5
#
#                         tests.TestWriteFile.data_path  \
# 0         agbenchmark/challenges/interface/write_file
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 58  agbenchmark/challenges/interface/write_file/da...
# 59  agbenchmark/challenges/interface/write_file/da...
# 60  agbenchmark/challenges/interface/write_file/da...
# 61  agbenchmark/challenges/interface/write_file/da...
# 62  agbenchmark/challenges/interface/write_file/da...
#
#    tests.TestWriteFile.is_regression tests.TestWriteFile.reached_cutoff  \
# 0                               True                              False
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# ..                               ...                                ...
# 58                              True                              False
# 59                              True                              False
# 60                              True                              False
# 61                              True                              False
# 62                              True                              False
#
#    tests.TestWriteFile.metrics.difficulty tests.TestWriteFile.metrics.success  \
# 0                               interface                                True
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
# ..                                    ...                                 ...
# 58                              interface                                True
# 59                              interface                                True
# 60                              interface                                True
# 61                              interface                                True
# 62                              interface                                True
#
#     tests.TestWriteFile.metrics.success_%  ...  \
# 0                                   100.0  ...
# 1                                     NaN  ...
# 2                                     NaN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
# ..                                    ...  ...
# 58                                  100.0  ...
# 59                                  100.0  ...
# 60                                  100.0  ...
# 61                                  100.0  ...
# 62                                  100.0  ...
#
#    tests.TestReturnCode_Tests.metrics.success  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 58                                      False
# 59                                      False
# 60                                      False
# 61                                      False
# 62                                      False
#
#        tests.TestReturnCode_Tests.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 58  agent/mini-agi/venv/lib/python3.10/site-packag...
# 59  agent/mini-agi/venv/lib/python3.10/site-packag...
# 60  agent/mini-agi/venv/lib/python3.10/site-packag...
# 61  agent/mini-agi/venv/lib/python3.10/site-packag...
# 62  agent/mini-agi/venv/lib/python3.10/site-packag...
#
#    tests.TestReturnCode_Tests.metrics.success_%  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 58                                          0.0
# 59                                          0.0
# 60                                          0.0
# 61                                          0.0
# 62                                          0.0
#
#    tests.TestReturnCode_Tests.metrics.run_time  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 58                               0.001 seconds
# 59                               0.001 seconds
# 60                               0.001 seconds
# 61                               0.001 seconds
# 62                               0.001 seconds
#
#    tests.TestReturnCode_Tests.reached_cutoff  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 58                                     False
# 59                                     False
# 60                                     False
# 61                                     False
# 62                                     False
#
#    tests.TestRememberMultiplePhrasesWithNoise.category  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 58                                           [memory]
# 59                                           [memory]
# 60                                           [memory]
# 61                                           [memory]
# 62                                           [memory]
#
#    tests.TestRetrieval3.category  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 58                   [retrieval]
# 59                   [retrieval]
# 60                   [retrieval]
# 61                   [retrieval]
# 62                   [retrieval]
#
#    tests.TestAdaptSimpleTypoWithGuidance.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 58                                  assert 1 in [0.0]
# 59                                  assert 1 in [0.0]
# 60                                                NaN
# 61                                  assert 1 in [0.0]
# 62                                  assert 1 in [0.0]
#
#               tests.TestAdaptLink.metrics.fail_reason  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 58  agent/mini-agi/venv/lib/python3.10/site-packag...
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                     assert 1 in []
#
#    tests.TestRevenueRetrieval_1.0.metrics.fail_reason
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 58  agent/mini-agi/venv/lib/python3.10/site-packag...
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
#
# [63 rows x 476 columns]
